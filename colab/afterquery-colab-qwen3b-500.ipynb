# %% [markdown]
# # RLVR TerminalBench Training on Colab
#
# Train a larger model (Qwen2.5-3B-Instruct) with GRPO on a free T4 GPU (15GB VRAM).
#
# **Runtime:** Go to Runtime > Change runtime type > Select **T4 GPU**

# %% [markdown]
# ## 1. Setup

# %%
# Check GPU
# !nvidia-smi
# Out:
# Fri Mar 27 18:01:58 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Install dependencies
# !pip install -q transformers trl accelerate datasets peft bitsandbytes pyyaml tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.0/531.0 kB 36.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.5 MB/s eta 0:00:00

# %%
# Clone the repo (or upload files manually)
# !git clone https://github.com/NathanG2022/rlvr-terminalbench.git 2>/dev/null || echo 'Repo already cloned'

# If repo is private or not on GitHub, upload the project files instead:
# from google.colab import files
# files.upload()  # upload a zip, then unzip

import os
os.chdir('rlvr-terminalbench')
print('Working directory:', os.getcwd())
# Out:
# Working directory: /content/rlvr-terminalbench

# %% [markdown]
# ## 2. Upload project files (if not using git clone)
#
# If your repo isn't on GitHub, run this cell and upload a zip of the project:

# %%
# Alternative: upload zip file
# from google.colab import files
# uploaded = files.upload()
# !unzip -o rlvr-terminalbench.zip
# os.chdir('rlvr-terminalbench')

# %% [markdown]
# ## 3. Verify GPU + imports

# %%
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    raise RuntimeError('No GPU found! Go to Runtime > Change runtime type > T4 GPU')
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %% [markdown]
# ## 4. Configure model and training

# %%
# Model choice - Qwen2.5-3B is free, no approval needed, 3x bigger than TinyLlama
MODEL_NAME = "Qwen/Qwen2.5-3B-Instruct"
# MODEL_NAME = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"  # smaller, for quick tests
# MODEL_NAME = "meta-llama/Llama-2-7b-chat-hf"  # needs HF approval + login

# Training params
NUM_PROMPTS = 128       # number of task prompts in dataset
TOTAL_STEPS = 500       # training steps (increase for better results)
BATCH_SIZE = 4          # prompts per batch
NUM_GENERATIONS = 4     # completions per prompt (more = better GRPO signal)
LEARNING_RATE = 5e-6
MAX_NEW_TOKENS = 64
MAX_STEPS_PER_EPISODE = 5

print(f'Model: {MODEL_NAME}')
print(f'Steps: {TOTAL_STEPS}, Batch: {BATCH_SIZE}, Generations: {NUM_GENERATIONS}')
# Out:
# Model: Qwen/Qwen2.5-3B-Instruct
# Steps: 500, Batch: 4, Generations: 4

# %% [markdown]
# ## 5. Build prompt dataset

# %%
import sys
sys.path.insert(0, '.')

from datasets import Dataset
from envs.terminalbench_client import TerminalBenchClient
from envs.terminalbench_env import TerminalBenchEnv

tb_client = TerminalBenchClient(command_timeout=10, max_output_length=2000)
env = TerminalBenchEnv(
    tb_client,
    max_steps=MAX_STEPS_PER_EPISODE,
    step_penalty=0.01,
    w_success=1.0,
    w_eff=0.1,
    w_quality=0.05,
)

prompts = []
for _ in range(NUM_PROMPTS):
    obs = env.reset()
    prompts.append({'prompt': obs})

train_dataset = Dataset.from_list(prompts)
print(f'Dataset: {len(train_dataset)} prompts')
print(f'\nExample prompt:\n{prompts[0]["prompt"][:300]}...')
# Out:
# Dataset: 128 prompts
#
# Example prompt:
# [terminalbench]
# Task: Write the last 5 lines of 'log.txt' to a file called 'last5.txt'.
# Difficulty: medium
# Step: 0/5
#
# Terminal history:
#
# You are a CLI assistant. Issue the next bash command to complete the task.
# Command:...

# %% [markdown]
# ## 6. Define reward function

# %%
import re

def extract_command(text: str) -> str:
    """Extract a single shell command from model output."""
    text = text.strip()
    if not text:
        return 'echo noop'

    m = re.search(r'```(?:bash|sh)?\s*\n(.+?)```', text, re.DOTALL)
    if m:
        for line in m.group(1).splitlines():
            line = line.strip()
            if line and not line.startswith('#'):
                return line

    for line in text.splitlines():
        line = line.strip()
        if not line or line.startswith('#'):
            continue
        if re.match(r'^[A-Z][a-z].*\s(the|a|an|is|to|you|can|this)\s', line):
            continue
        return line

    return text.splitlines()[0].strip() or 'echo noop'


def make_reward_func():
    tb_client = TerminalBenchClient(command_timeout=10, max_output_length=2000)
    env = TerminalBenchEnv(
        tb_client,
        max_steps=MAX_STEPS_PER_EPISODE,
        step_penalty=0.01,
        w_success=1.0,
        w_eff=0.1,
        w_quality=0.05,
    )

    def reward_func(prompts, completions, **kwargs):
        rewards = []
        for prompt, completion in zip(prompts, completions):
            command = extract_command(completion)
            env.reset()
            _obs, reward, _done, _info = env.step(command)
            rewards.append(reward)
        return rewards

    return reward_func

reward_func = make_reward_func()
print('Reward function ready')
# Out:
# Reward function ready

# %% [markdown]
# ## 7. Load model with 4-bit quantization + LoRA

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type='nf4',
)

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=quantization_config,
)

peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    target_modules=['q_proj', 'v_proj'],
)

# Check memory usage
if torch.cuda.is_available():
    mem_used = torch.cuda.memory_allocated() / 1e9
    mem_total = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f'GPU memory: {mem_used:.1f} / {mem_total:.1f} GB')

print('Model loaded')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# GPU memory: 2.2 / 15.6 GB
# Model loaded

# %% [markdown]
# ## 8. Train with GRPO

# %%
from trl import GRPOConfig, GRPOTrainer

OUTPUT_DIR = 'models/rlvr_colab'

grpo_config = GRPOConfig(
    output_dir=OUTPUT_DIR,
    learning_rate=LEARNING_RATE,
    per_device_train_batch_size=BATCH_SIZE,
    num_generations=NUM_GENERATIONS,
    num_train_epochs=1,
    max_steps=TOTAL_STEPS,
    max_completion_length=MAX_NEW_TOKENS,
    temperature=0.7,
    top_p=0.9,
    beta=0.04,
    logging_steps=10,
    save_strategy='steps',
    save_steps=100,
    report_to='none',
    bf16=torch.cuda.is_bf16_supported(),
    fp16=not torch.cuda.is_bf16_supported(),
    gradient_checkpointing=True,
)

trainer = GRPOTrainer(
    model=model,
    reward_funcs=reward_func,
    args=grpo_config,
    train_dataset=train_dataset,
    peft_config=peft_config,
)

print(f'Training for {TOTAL_STEPS} steps...')
trainer.train()
trainer.save_model(OUTPUT_DIR)
print(f'Model saved to {OUTPUT_DIR}')
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# Training for 500 steps...
# Passing `generation_config` together with generation-related arguments=({'disable_compile'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 3:01:33, Epoch 3/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.000153</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000080</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000083</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000074</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000085</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000072</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000073</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000630</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000060</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000076</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.000073</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.000913</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.000086</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.000121</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.000072</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.000112</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.000065</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.000074</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.000054</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.000118</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.000074</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.000077</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.000073</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.000078</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.000075</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.000103</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.000059</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.000092</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.000083</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.000116</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.000065</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.000069</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.000076</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.000113</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.000077</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.000079</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.000085</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.000154</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.000091</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.000119</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.000086</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.000076</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.000102</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.000056</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.000062</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.000504</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.000075</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.070305</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.000066</td>
#     </tr>
#   </tbody>
# </table><p>
# Model saved to models/rlvr_colab

# %% [markdown]
# ## 9. Evaluate trained model

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from statistics import mean

def evaluate_model(model_path, num_episodes=20):
    """Evaluate a model on terminalbench tasks."""
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    eval_model = AutoModelForCausalLM.from_pretrained(model_path).eval().cuda()
    max_ctx = getattr(eval_model.config, 'max_position_embeddings', 2048)

    tb_client = TerminalBenchClient(command_timeout=10, max_output_length=2000)
    env = TerminalBenchEnv(
        tb_client, max_steps=MAX_STEPS_PER_EPISODE,
        step_penalty=0.01, w_success=1.0, w_eff=0.1, w_quality=0.05,
    )

    scores, steps = [], []
    for ep in range(num_episodes):
        obs = env.reset()
        done = False
        task_id = env.task.task_id if env.task else 'unknown'
        last_score = 0.0

        while not done:
            max_new = MAX_NEW_TOKENS
            inputs = tokenizer(
                obs, return_tensors='pt', truncation=True,
                max_length=max_ctx - max_new,
            ).to(eval_model.device)
            out_ids = eval_model.generate(
                inputs['input_ids'],
                attention_mask=inputs['attention_mask'],
                max_new_tokens=max_new,
                do_sample=True,
                temperature=0.7,
                top_p=0.9,
                pad_token_id=tokenizer.eos_token_id,
            )
            new_ids = out_ids[0][inputs['input_ids'].shape[1]:]
            action = tokenizer.decode(new_ids, skip_special_tokens=True).strip()
            action = action.split('\n')[0].strip().lstrip('$ ').strip()
            print(f'  ep{ep+1} step{env.step_count+1}: {action[:80]}')
            obs, _reward, done, info = env.step(action)
            last_score = info['success_score']

        scores.append(last_score)
        steps.append(info['step_count'])
        print(f'  -> task={task_id} score={last_score:.2f} steps={info["step_count"]}')

    # Free GPU memory
    del eval_model
    torch.cuda.empty_cache()

    return {
        'mean_score': mean(scores),
        'success_rate': mean(1.0 if s >= 1.0 else 0.0 for s in scores),
        'mean_steps': mean(steps),
    }

# %%
NUM_EVAL_EPISODES = 20

print('=== Evaluating TRAINED model ===')
trained_results = evaluate_model(OUTPUT_DIR, num_episodes=NUM_EVAL_EPISODES)

print(f'\n=== Evaluating BASE model ({MODEL_NAME}) ===')
base_results = evaluate_model(MODEL_NAME, num_episodes=NUM_EVAL_EPISODES)

print('\n' + '='*50)
print(f'{"Metric":<25} {"Base":>10} {"Trained":>10}')
print('-'*50)
print(f'{"Mean score":<25} {base_results["mean_score"]:>10.3f} {trained_results["mean_score"]:>10.3f}')
print(f'{"Success rate":<25} {base_results["success_rate"]:>10.3f} {trained_results["success_rate"]:>10.3f}')
print(f'{"Mean steps":<25} {base_results["mean_steps"]:>10.2f} {trained_results["mean_steps"]:>10.2f}')
print('='*50)
# Out:
# === Evaluating TRAINED model ===
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/144 [00:00<?, ?it/s]
#   ep1 step1: `sort unsorted.txt > sorted.txt`
#   -> task=med_sort_file score=1.00 steps=1
#   ep2 step1: `sort unsorted.txt -o sorted.txt` To sort the contents of `unsorted.txt` alphabe
#   -> task=med_sort_file score=1.00 steps=1
#   ep3 step1: ls > listing.txt
#   -> task=easy_list_files score=1.00 steps=1
#   ep4 step1: ```bash
#   ep4 step2: ```
#   ep4 step3: ```bash
#   ep4 step4: ```bash
#   ep4 step5: ```bash
#   -> task=med_grep_errors score=0.00 steps=5
#   ep5 step1: ```bash
#   ep5 step2: ```bash
#   ep5 step3: ```bash
#   ep5 step4: ```bash
#   ep5 step5: ```bash
#   -> task=med_unique_words score=0.00 steps=5
#   ep6 step1: `jq -r '.database.name' config.json | tee dbname.txt`
#   -> task=hard_json_extract score=1.00 steps=1
#   ep7 step1: `find . -name "*.txt" -type f -print | tee results.txt`
#   -> task=med_find_txt score=1.00 steps=1
#   ep8 step1: ```
#   ep8 step2: ```
#   ep8 step3: ```
#   ep8 step4: ```bash
#   ep8 step5: ```bash
#   -> task=hard_shell_script score=0.00 steps=5
#   ep9 step1: cat words.txt | tr -s ' ' '\n' | sort | uniq -c | sort -nr | awk '{print $2": "$
#   ep9 step2: ```
#   ep9 step3: ``cat words.txt | tr -s ' ' '\n' | sort | uniq -c | sort -nr | awk '{print \$2":
#   ep9 step4: cat words.txt | tr -s ' ' '\n' | sort | uniq -c | sort -nr | awk '{print \$2": "
#   ep9 step5: ```bash
#   -> task=med_word_freq score=0.00 steps=5
#   ep10 step1: mkdir mydir
#   -> task=easy_create_dir score=1.00 steps=1
#   ep11 step1: `awk '{print $1}' server.log | sort -u > timestamps.txt`
#   -> task=hard_log_pipeline score=1.00 steps=1
#   ep12 step1: `grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort -n | uniq > ti
#   ep12 step2: `grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort -n | uniq | so
#   ep12 step3: `grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort -n | uniq | so
#   ep12 step4: `grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort -n | uniq | so
#   ep12 step5: ```bash
#   -> task=hard_log_pipeline score=0.00 steps=5
#   ep13 step1: find . -type f -name '*.txt' -print | tee results.txt
#   -> task=med_find_txt score=1.00 steps=1
#   ep14 step1: cat data.txt | wc -l > count.txt
#   -> task=easy_count_lines score=1.00 steps=1
#   ep15 step1: `find . -name "*.txt" -type f -print > results.txt` Step: 1/5
#   -> task=med_find_txt score=1.00 steps=1
#   ep16 step1: cp source.txt dest.txt
#   -> task=easy_copy_file score=1.00 steps=1
#   ep17 step1: `cut -d',' -f1 data.csv > names.txt`
#   -> task=med_csv_column score=1.00 steps=1
#   ep18 step1: ```
#   ep18 step2: ```bash
#   ep18 step3: ```
#   ep18 step4: ```
#   ep18 step5: ```bash
#   -> task=hard_shell_script score=0.00 steps=5
#   ep19 step1: `grep -E 'ERROR|CRITICAL' app.log > errors.txt` Step: 1/5
#   -> task=med_grep_errors score=1.00 steps=1
#   ep20 step1: ls > listing.txt
#   -> task=easy_list_files score=1.00 steps=1
#
# === Evaluating BASE model (Qwen/Qwen2.5-3B-Instruct) ===
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
#   ep1 step1: `tar -czvf archive.tar.gz project/`
#   -> task=hard_tar_archive score=1.00 steps=1
#   ep2 step1: ```bash
#   ep2 step2: ```bash
#   ep2 step3: ```bash
#   ep2 step4: ```bash
#   ep2 step5: ```bash
#   -> task=hard_shell_script score=0.00 steps=5
#   ep3 step1: `cat words.txt | tr '[:upper:]' '[:lower:]' | grep -i "[a-z]+" | sort | uniq -c
#   ep3 step2: `cat words.txt | tr '[:upper:]' '[:lower:]' | grep -i "[a-z]+" | sort | uniq -c
#   ep3 step3: `cat words.txt | tr '[:upper:]' '[:lower:]' | grep -i "[a-z]+" | sort | uniq -c
#   ep3 step4: ```bash
#   ep3 step5: ```bash
#   -> task=med_word_freq score=0.00 steps=5
#   ep4 step1: `mv old.txt new.txt`
#   -> task=easy_rename_file score=1.00 steps=1
#   ep5 step1: `find . -name "*.txt" -type f -print | tee results.txt` Step: 1/5
#   -> task=med_find_txt score=1.00 steps=1
#   ep6 step1: `wc -l data.txt | awk '{print $1}' > count.txt`
#   -> task=easy_count_lines score=1.00 steps=1
#   ep7 step1: ```bash
#   ep7 step2: ```bash
#   ep7 step3: cat log.txt | tail -n 5 > last5.txt
#   -> task=med_tail_file score=1.00 steps=3
#   ep8 step1: ```bash
#   ep8 step2: ```
#   ep8 step3: ```bash
#   ep8 step4: ```
#   ep8 step5: ```bash
#   -> task=hard_shell_script score=0.00 steps=5
#   ep9 step1: `mv old.txt new.txt` To rename the file 'old.txt' to 'new.txt', you can use the
#   ep9 step2: `/usr/bin/mv /tmp/tb_easy_rename_file_ya6nuom3/old.txt /tmp/tb_easy_rename_file_
#   -> task=easy_rename_file score=1.00 steps=2
#   ep10 step1: `sort unsorted.txt -o sorted.txt`
#   -> task=med_sort_file score=1.00 steps=1
#   ep11 step1: `ls > listing.txt` Step: 1/5
#   -> task=easy_list_files score=1.00 steps=1
#   ep12 step1: `grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort | uniq -c | so
#   ep12 step2: `$ grep -oE '\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}' server.log | sort | uniq -c |
#   ep12 step3: ```bash
#   ep12 step4: ```bash
#   ep12 step5: ```bash
#   -> task=hard_log_pipeline score=0.00 steps=5
#   ep13 step1: `find . -type f -size +100c -print | sort -k5nr | tee large.txt` To find all fil
#   -> task=hard_find_large score=1.00 steps=1
#   ep14 step1: ```bash
#   ep14 step2: ```bash
#   ep14 step3: ```
#   ep14 step4: ```bash
#   ep14 step5: ```bash
#   -> task=hard_shell_script score=0.00 steps=5
#   ep15 step1: `grep -E "ERROR" app.log > errors.txt` To extract all lines containing 'ERROR' f
#   -> task=med_grep_errors score=1.00 steps=1
#   ep16 step1: `mv old.txt new.txt` To rename the file `old.txt` to `new.txt`, you can use the
#   -> task=easy_rename_file score=1.00 steps=1
#   ep17 step1: `cat words.txt | tr ' ' '\n' | sort | uniq -c | sort -nr > freq.txt` Step: 1/5
#   -> task=med_word_freq score=1.00 steps=1
#   ep18 step1: `find . -type f -size +100c -exec ls -lS {} \; | awk '{print $9}' > large.txt`
#   -> task=hard_find_large score=1.00 steps=1
#   ep19 step1: `wc -l < data.txt > count.txt` To count the number of lines in the file `data.tx
#   -> task=easy_count_lines score=1.00 steps=1
#   ep20 step1: ls > listing.txt
#   -> task=easy_list_files score=1.00 steps=1
#
# ==================================================
# Metric                          Base    Trained
# --------------------------------------------------
# Mean score                     0.750      0.700
# Success rate                   0.750      0.700
# Mean steps                      2.15       2.20
# ==================================================

# %% [markdown]
# ## 10. Download trained model

# %%
# Zip and download the trained model
# !zip -r models/rlvr_colab.zip models/rlvr_colab/

from google.colab import files
files.download('models/rlvr_colab.zip')
# Out:
#   adding: models/rlvr_colab/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-400/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-400/trainer_state.json (deflated 89%)
#   adding: models/rlvr_colab/checkpoint-400/optimizer.pt (deflated 22%)
#   adding: models/rlvr_colab/checkpoint-400/README.md (deflated 66%)
#   adding: models/rlvr_colab/checkpoint-400/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-400/scheduler.pt (deflated 61%)
#   adding: models/rlvr_colab/checkpoint-400/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/checkpoint-400/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/checkpoint-400/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/checkpoint-400/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/checkpoint-400/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-400/rng_state.pth (deflated 26%)
#   adding: models/rlvr_colab/README.md (deflated 47%)
#   adding: models/rlvr_colab/checkpoint-300/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-300/trainer_state.json (deflated 89%)
#   adding: models/rlvr_colab/checkpoint-300/optimizer.pt (deflated 22%)
#   adding: models/rlvr_colab/checkpoint-300/README.md (deflated 66%)
#   adding: models/rlvr_colab/checkpoint-300/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-300/scheduler.pt (deflated 61%)
#   adding: models/rlvr_colab/checkpoint-300/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/checkpoint-300/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/checkpoint-300/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/checkpoint-300/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/checkpoint-300/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-300/rng_state.pth (deflated 26%)
#   adding: models/rlvr_colab/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-200/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-200/trainer_state.json (deflated 87%)
#   adding: models/rlvr_colab/checkpoint-200/optimizer.pt (deflated 22%)
#   adding: models/rlvr_colab/checkpoint-200/README.md (deflated 66%)
#   adding: models/rlvr_colab/checkpoint-200/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-200/scheduler.pt (deflated 61%)
#   adding: models/rlvr_colab/checkpoint-200/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/checkpoint-200/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/checkpoint-200/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/checkpoint-200/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/checkpoint-200/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-200/rng_state.pth (deflated 26%)
#   adding: models/rlvr_colab/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-100/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-100/trainer_state.json (deflated 84%)
#   adding: models/rlvr_colab/checkpoint-100/optimizer.pt (deflated 22%)
#   adding: models/rlvr_colab/checkpoint-100/README.md (deflated 66%)
#   adding: models/rlvr_colab/checkpoint-100/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-100/scheduler.pt (deflated 61%)
#   adding: models/rlvr_colab/checkpoint-100/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/checkpoint-100/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/checkpoint-100/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/checkpoint-100/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/checkpoint-100/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-100/rng_state.pth (deflated 26%)
#   adding: models/rlvr_colab/checkpoint-500/ (stored 0%)
#   adding: models/rlvr_colab/checkpoint-500/trainer_state.json (deflated 90%)
#   adding: models/rlvr_colab/checkpoint-500/optimizer.pt (deflated 22%)
#   adding: models/rlvr_colab/checkpoint-500/README.md (deflated 66%)
#   adding: models/rlvr_colab/checkpoint-500/tokenizer_config.json (deflated 59%)
#   adding: models/rlvr_colab/checkpoint-500/scheduler.pt (deflated 62%)
#   adding: models/rlvr_colab/checkpoint-500/training_args.bin (deflated 53%)
#   adding: models/rlvr_colab/checkpoint-500/chat_template.jinja (deflated 71%)
#   adding: models/rlvr_colab/checkpoint-500/adapter_config.json (deflated 57%)
#   adding: models/rlvr_colab/checkpoint-500/adapter_model.safetensors (deflated 21%)
#   adding: models/rlvr_colab/checkpoint-500/tokenizer.json (deflated 81%)
#   adding: models/rlvr_colab/checkpoint-500/rng_state.pth (deflated 26%)
